# %% [markdown]
# In data/Raw/data, there should be the CSV files for the input data for the desired time period. The data in the git repository has already been pre-processed, so this step can be skipped. The raw CSV files are not in the repository, as they are too large.

# %%
import src.maritime_domain_awareness.preproccesing as pp
pp.preprocess(
        "data/Raw/data", 
        "data/Processed",
        "data/preprocessed/raw_segmented.parquet",
)

# %% [markdown]
# When training, the models directory should be empty. The git repository includes the trained models, so this step can be skipped.

# %%
import src.maritime_domain_awareness.train as train

train.main()

# %% [markdown]
# The file in visualize should be a parquet file that was generated in preprocess. If new files have been generated, the below example will not work

# %%
import src.maritime_domain_awareness.visualize as visualize

visualize.main("data/Processed/MMSI=219000897/Segment=0/01a7aeea3f8d40ccbc3c933cd5c72f6e-0.parquet")
# Out:
# Distance between Warsaw and Rome: 1315510.16 meters
#
# Loading available models...
# Model Name: transformer
# Input features (n_in): 4
# Hidden features (n_hid): 256
# Output features (n_out): 4
# Number of layers (num_layers): 3
# Number of heads (n_heads): 4
# Dimension of feedforward (dim_feedforward): 1024
# Dropout rate: 0.2
# Batch first: False
# Max sequence length (max_len): 5000
# ✓ TRANSFORMER loaded
# Model Name: rnn
# Input features (n_in): 4
# Hidden features (n_hid): 256
# Output features (n_out): 4
# Number of layers (num_layers): 1
# Batch first: False
# Dropout rate: 0.0
# Activation function: tanh
# ✓ RNN loaded
# Model Name: lstm
# Input features (n_in): 4
# Hidden features (n_hid): 256
# Output features (n_out): 4
# Number of layers (num_layers): 2
# Bias: True
# Batch first: False
# Dropout rate: 0.2
# ✓ LSTM loaded
# Model Name: gru
# Input features (n_in): 4
# Hidden features (n_hid): 256
# Output features (n_out): 4
# Number of layers (num_layers): 2
# Batch first: False
# Dropout rate: 0.2
# ✓ GRU loaded
#
# Running predictions for 5 models...
#
# Running TRANSFORMER...
# /home/jonas/asdhashd/Maritime_Domain_Awareness/.venv/lib64/python3.13/site-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# TRANSFORMER error: 7237.1 meters
# Running RNN...
# RNN error: 11066.6 meters
# Running LSTM...
# LSTM error: 10117.6 meters
# Running GRU...
# GRU error: 8864.1 meters
# Running Kalman Filter...
# Kalman Filter error: 11212.8 meters
# ==================================================
# SUMMARY OF RESULTS
# ==================================================
# TRANSFORMER         :   7237.1 meters
# RNN                 :  11066.6 meters
# LSTM                :  10117.6 meters
# GRU                 :   8864.1 meters
# Kalman Filter       :  11212.8 meters
# ==================================================
